# %%
# %pip install cellpose
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: cellpose in /home/longdnk/.local/lib/python3.10/site-packages (2.2.3)
# Requirement already satisfied: fastremap in /home/longdnk/.local/lib/python3.10/site-packages (from cellpose) (1.14.1)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.10/dist-packages (from cellpose) (2023.12.9)
# Requirement already satisfied: natsort in /home/longdnk/.local/lib/python3.10/site-packages (from cellpose) (8.4.0)
# Requirement already satisfied: torch>=1.6 in /home/longdnk/.local/lib/python3.10/site-packages (from cellpose) (2.1.2)
# Requirement already satisfied: opencv-python-headless in /home/longdnk/.local/lib/python3.10/site-packages (from cellpose) (4.8.1.78)
# Requirement already satisfied: imagecodecs in /home/longdnk/.local/lib/python3.10/site-packages (from cellpose) (2023.9.18)
# Requirement already satisfied: roifile in /home/longdnk/.local/lib/python3.10/site-packages (from cellpose) (2023.8.30)
# Requirement already satisfied: tqdm in /home/longdnk/.local/lib/python3.10/site-packages (from cellpose) (4.66.1)
# Requirement already satisfied: numba>=0.53.0 in /home/longdnk/.local/lib/python3.10/site-packages (from cellpose) (0.58.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from cellpose) (1.11.4)
# Requirement already satisfied: llvmlite in /home/longdnk/.local/lib/python3.10/site-packages (from cellpose) (0.41.1)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from cellpose) (1.26.2)
# Requirement already satisfied: fsspec in /home/longdnk/.local/lib/python3.10/site-packages (from torch>=1.6->cellpose) (2023.12.2)
# Requirement already satisfied: typing-extensions in /home/longdnk/.local/lib/python3.10/site-packages (from torch>=1.6->cellpose) (4.9.0)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/longdnk/.local/lib/python3.10/site-packages (from torch>=1.6->cellpose) (8.9.2.26)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/longdnk/.local/lib/python3.10/site-packages (from torch>=1.6->cellpose) (11.4.5.107)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /home/longdnk/.local/lib/python3.10/site-packages (from torch>=1.6->cellpose) (2.18.1)
# Requirement already satisfied: sympy in /usr/lib/python3/dist-packages (from torch>=1.6->cellpose) (1.9)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6->cellpose) (3.2.1)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/longdnk/.local/lib/python3.10/site-packages (from torch>=1.6->cellpose) (12.1.105)
# Requirement already satisfied: jinja2 in /home/longdnk/.local/lib/python3.10/site-packages (from torch>=1.6->cellpose) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/longdnk/.local/lib/python3.10/site-packages (from torch>=1.6->cellpose) (12.1.105)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/longdnk/.local/lib/python3.10/site-packages (from torch>=1.6->cellpose) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /home/longdnk/.local/lib/python3.10/site-packages (from torch>=1.6->cellpose) (2.1.0)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/longdnk/.local/lib/python3.10/site-packages (from torch>=1.6->cellpose) (11.0.2.54)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/longdnk/.local/lib/python3.10/site-packages (from torch>=1.6->cellpose) (12.1.0.106)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/longdnk/.local/lib/python3.10/site-packages (from torch>=1.6->cellpose) (12.1.3.1)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/longdnk/.local/lib/python3.10/site-packages (from torch>=1.6->cellpose) (10.3.2.106)
# Requirement already satisfied: filelock in /home/longdnk/.local/lib/python3.10/site-packages (from torch>=1.6->cellpose) (3.13.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/longdnk/.local/lib/python3.10/site-packages (from torch>=1.6->cellpose) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/longdnk/.local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.6->cellpose) (12.3.101)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/longdnk/.local/lib/python3.10/site-packages (from jinja2->torch>=1.6->cellpose) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from cellpose import models

# %%
import skimage.io
import matplotlib.pyplot as plt

# %%
image = skimage.io.imread('./19838_1252_F8_1.tif')

# %%
image.shape
# Out:
# (2048, 2048, 3)

# %%
image = image[::4, :: 4, :]

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ax.imshow(image);

# %%
model = models.Cellpose(model_type='cyto')

# %%
channels = [[1, 3]]
masks, flows, styles, diams = model.eval(image, diameter=None, channels=channels)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ax.imshow(image[:, :, 0], cmap='gray')
ax.imshow(masks, alpha=0.5);

# %%
masks, flows, styles, diams = model.eval(image, diameter=100, channels=channels)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ax.imshow(image[:, :, 0], cmap='gray')
ax.imshow(masks, alpha=0.5);

# %%
model = models.Cellpose(model_type='nuclei')

channels = [3, 0]
masks, flows, styles, diams = model.eval(image, diameter=100, channels=channels)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ax.imshow(image[:, :, 2], cmap='gray')
ax.imshow(masks, alpha=0.5);

# %%
# %pip install napari
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: napari in /home/longdnk/.local/lib/python3.10/site-packages (0.4.18)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.10/dist-packages (from napari) (1.26.2)
# Requirement already satisfied: numpydoc>=0.9.2 in /home/longdnk/.local/lib/python3.10/site-packages (from napari) (1.5.0)
# Requirement already satisfied: certifi>=2018.1.18 in /usr/lib/python3/dist-packages (from napari) (2020.6.20)
# Requirement already satisfied: tqdm>=4.56.0 in /home/longdnk/.local/lib/python3.10/site-packages (from napari) (4.66.1)
# Requirement already satisfied: npe2>=0.5.2 in /home/longdnk/.local/lib/python3.10/site-packages (from napari) (0.7.3)
# Requirement already satisfied: napari-console>=0.0.6 in /home/longdnk/.local/lib/python3.10/site-packages (from napari) (0.0.9)
# Requirement already satisfied: psygnal>=0.3.4 in /home/longdnk/.local/lib/python3.10/site-packages (from napari) (0.9.5)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/lib/python3/dist-packages (from napari) (1.4.4)
# Requirement already satisfied: PyYAML>=5.1 in /usr/lib/python3/dist-packages (from napari) (5.4.1)
# Requirement already satisfied: psutil>=5.0 in /home/longdnk/.local/lib/python3.10/site-packages (from napari) (5.9.7)
# Requirement already satisfied: Pillow!=7.1.0,!=7.1.1 in /usr/local/lib/python3.10/dist-packages (from napari) (10.1.0)
# Requirement already satisfied: cachey>=0.2.1 in /home/longdnk/.local/lib/python3.10/site-packages (from napari) (0.2.1)
# Requirement already satisfied: napari-svg>=0.1.7 in /home/longdnk/.local/lib/python3.10/site-packages (from napari) (0.1.10)
# Requirement already satisfied: napari-plugin-engine>=0.1.9 in /home/longdnk/.local/lib/python3.10/site-packages (from napari) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/longdnk/.local/lib/python3.10/site-packages (from napari) (4.9.0)
# Requirement already satisfied: magicgui>=0.3.6 in /home/longdnk/.local/lib/python3.10/site-packages (from napari) (0.8.1)
# Requirement already satisfied: PyOpenGL>=3.1.0 in /home/longdnk/.local/lib/python3.10/site-packages (from napari) (3.1.7)
# Requirement already satisfied: imageio!=2.22.1,>=2.20 in /usr/local/lib/python3.10/dist-packages (from napari) (2.33.1)
# Requirement already satisfied: app-model<0.3.0,>=0.1.0 in /home/longdnk/.local/lib/python3.10/site-packages (from napari) (0.2.4)
# Requirement already satisfied: tifffile>=2020.2.16 in /usr/local/lib/python3.10/dist-packages (from napari) (2023.12.9)
# Requirement already satisfied: dask[array]!=2.28.0,>=2.15.0 in /home/longdnk/.local/lib/python3.10/site-packages (from napari) (2023.12.1)
# Requirement already satisfied: scikit-image[data]>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from napari) (0.22.0)
# Requirement already satisfied: superqt>=0.4.1 in /home/longdnk/.local/lib/python3.10/site-packages (from napari) (0.6.1)
# Requirement already satisfied: wrapt>=1.11.1 in /home/longdnk/.local/lib/python3.10/site-packages (from napari) (1.16.0)
# Requirement already satisfied: pydantic<2,>=1.9.0 in /home/longdnk/.local/lib/python3.10/site-packages (from napari) (1.10.13)
# Requirement already satisfied: vispy<0.13,>=0.12.1 in /home/longdnk/.local/lib/python3.10/site-packages (from napari) (0.12.2)
# Requirement already satisfied: jsonschema>=3.2.0 in /home/longdnk/.local/lib/python3.10/site-packages (from napari) (4.20.0)
# Requirement already satisfied: pygments>=2.6.0 in /home/longdnk/.local/lib/python3.10/site-packages (from napari) (2.17.2)
# Requirement already satisfied: qtpy>=1.10.0 in /home/longdnk/.local/lib/python3.10/site-packages (from napari) (2.4.1)
# Requirement already satisfied: pint>=0.17 in /home/longdnk/.local/lib/python3.10/site-packages (from napari) (0.23)
# Requirement already satisfied: lazy-loader>=0.2 in /usr/local/lib/python3.10/dist-packages (from napari) (0.3)
# Requirement already satisfied: toolz>=0.10.0 in /home/longdnk/.local/lib/python3.10/site-packages (from napari) (0.12.0)
# Requirement already satisfied: scipy>=1.5.4 in /usr/local/lib/python3.10/dist-packages (from napari) (1.11.4)
# Requirement already satisfied: pandas>=1.3.0 in /home/longdnk/.local/lib/python3.10/site-packages (from napari) (2.1.4)
# Requirement already satisfied: sphinx<5,>=4.3.0 in /home/longdnk/.local/lib/python3.10/site-packages (from napari) (4.5.0)
# Requirement already satisfied: pydantic-compat>=0.1.1 in /home/longdnk/.local/lib/python3.10/site-packages (from app-model<0.3.0,>=0.1.0->napari) (0.1.2)
# Requirement already satisfied: in-n-out>=0.1.5 in /home/longdnk/.local/lib/python3.10/site-packages (from app-model<0.3.0,>=0.1.0->napari) (0.1.9)
# Requirement already satisfied: heapdict in /home/longdnk/.local/lib/python3.10/site-packages (from cachey>=0.2.1->napari) (1.0.1)
# Requirement already satisfied: click>=8.1 in /home/longdnk/.local/lib/python3.10/site-packages (from dask[array]!=2.28.0,>=2.15.0->napari) (8.1.7)
# Requirement already satisfied: fsspec>=2021.09.0 in /home/longdnk/.local/lib/python3.10/site-packages (from dask[array]!=2.28.0,>=2.15.0->napari) (2023.12.2)
# Requirement already satisfied: cloudpickle>=1.5.0 in /home/longdnk/.local/lib/python3.10/site-packages (from dask[array]!=2.28.0,>=2.15.0->napari) (3.0.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from dask[array]!=2.28.0,>=2.15.0->napari) (23.2)
# Requirement already satisfied: partd>=1.2.0 in /home/longdnk/.local/lib/python3.10/site-packages (from dask[array]!=2.28.0,>=2.15.0->napari) (1.4.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /home/longdnk/.local/lib/python3.10/site-packages (from dask[array]!=2.28.0,>=2.15.0->napari) (7.0.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/longdnk/.local/lib/python3.10/site-packages (from jsonschema>=3.2.0->napari) (2023.12.1)
# Requirement already satisfied: attrs>=22.2.0 in /home/longdnk/.local/lib/python3.10/site-packages (from jsonschema>=3.2.0->napari) (23.1.0)
# Requirement already satisfied: referencing>=0.28.4 in /home/longdnk/.local/lib/python3.10/site-packages (from jsonschema>=3.2.0->napari) (0.32.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/longdnk/.local/lib/python3.10/site-packages (from jsonschema>=3.2.0->napari) (0.15.2)
# Requirement already satisfied: docstring-parser>=0.7 in /home/longdnk/.local/lib/python3.10/site-packages (from magicgui>=0.3.6->napari) (0.15)
# Requirement already satisfied: IPython>=7.7.0 in /home/longdnk/.local/lib/python3.10/site-packages (from napari-console>=0.0.6->napari) (8.19.0)
# Requirement already satisfied: ipykernel>=5.2.0 in /home/longdnk/.local/lib/python3.10/site-packages (from napari-console>=0.0.6->napari) (6.28.0)
# Requirement already satisfied: qtconsole!=4.7.6,!=5.4.2,>=4.5.1 in /home/longdnk/.local/lib/python3.10/site-packages (from napari-console>=0.0.6->napari) (5.5.1)
# Requirement already satisfied: build>=1 in /home/longdnk/.local/lib/python3.10/site-packages (from npe2>=0.5.2->napari) (1.0.3)
# Requirement already satisfied: typer in /home/longdnk/.local/lib/python3.10/site-packages (from npe2>=0.5.2->napari) (0.9.0)
# Requirement already satisfied: tomli in /home/longdnk/.local/lib/python3.10/site-packages (from npe2>=0.5.2->napari) (2.0.1)
# Requirement already satisfied: tomli-w in /home/longdnk/.local/lib/python3.10/site-packages (from npe2>=0.5.2->napari) (1.0.0)
# Requirement already satisfied: rich in /home/longdnk/.local/lib/python3.10/site-packages (from npe2>=0.5.2->napari) (13.7.0)
# Requirement already satisfied: Jinja2>=2.10 in /home/longdnk/.local/lib/python3.10/site-packages (from numpydoc>=0.9.2->napari) (3.1.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/longdnk/.local/lib/python3.10/site-packages (from pandas>=1.3.0->napari) (2023.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->napari) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas>=1.3.0->napari) (2022.1)
# Requirement already satisfied: mypy-extensions in /home/longdnk/.local/lib/python3.10/site-packages (from psygnal>=0.3.4->napari) (1.0.0)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image[data]>=0.19.1->napari) (3.2.1)
# Requirement already satisfied: pooch>=1.6.0 in /home/longdnk/.local/lib/python3.10/site-packages (from scikit-image[data]>=0.19.1->napari) (1.8.0)
# Requirement already satisfied: sphinxcontrib-jsmath in /home/longdnk/.local/lib/python3.10/site-packages (from sphinx<5,>=4.3.0->napari) (1.0.1)
# Requirement already satisfied: docutils<0.18,>=0.14 in /home/longdnk/.local/lib/python3.10/site-packages (from sphinx<5,>=4.3.0->napari) (0.17.1)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in /home/longdnk/.local/lib/python3.10/site-packages (from sphinx<5,>=4.3.0->napari) (1.1.5)
# Requirement already satisfied: babel>=1.3 in /home/longdnk/.local/lib/python3.10/site-packages (from sphinx<5,>=4.3.0->napari) (2.14.0)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /home/longdnk/.local/lib/python3.10/site-packages (from sphinx<5,>=4.3.0->napari) (0.7.13)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /home/longdnk/.local/lib/python3.10/site-packages (from sphinx<5,>=4.3.0->napari) (2.0.1)
# Requirement already satisfied: snowballstemmer>=1.1 in /home/longdnk/.local/lib/python3.10/site-packages (from sphinx<5,>=4.3.0->napari) (2.2.0)
# Requirement already satisfied: sphinxcontrib-devhelp in /home/longdnk/.local/lib/python3.10/site-packages (from sphinx<5,>=4.3.0->napari) (1.0.2)
# Requirement already satisfied: sphinxcontrib-applehelp in /home/longdnk/.local/lib/python3.10/site-packages (from sphinx<5,>=4.3.0->napari) (1.0.4)
# Requirement already satisfied: imagesize in /home/longdnk/.local/lib/python3.10/site-packages (from sphinx<5,>=4.3.0->napari) (1.4.1)
# Requirement already satisfied: sphinxcontrib-qthelp in /home/longdnk/.local/lib/python3.10/site-packages (from sphinx<5,>=4.3.0->napari) (1.0.3)
# Requirement already satisfied: requests>=2.5.0 in /home/longdnk/.local/lib/python3.10/site-packages (from sphinx<5,>=4.3.0->napari) (2.31.0)
# Requirement already satisfied: hsluv in /home/longdnk/.local/lib/python3.10/site-packages (from vispy<0.13,>=0.12.1->napari) (5.0.4)
# Requirement already satisfied: kiwisolver in /usr/local/lib/python3.10/dist-packages (from vispy<0.13,>=0.12.1->napari) (1.4.5)
# Requirement already satisfied: freetype-py in /home/longdnk/.local/lib/python3.10/site-packages (from vispy<0.13,>=0.12.1->napari) (2.4.0)
# Requirement already satisfied: pyproject_hooks in /home/longdnk/.local/lib/python3.10/site-packages (from build>=1->npe2>=0.5.2->napari) (1.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/lib/python3/dist-packages (from importlib-metadata>=4.13.0->dask[array]!=2.28.0,>=2.15.0->napari) (1.0.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/longdnk/.local/lib/python3.10/site-packages (from ipykernel>=5.2.0->napari-console>=0.0.6->napari) (0.1.6)
# Requirement already satisfied: debugpy>=1.6.5 in /home/longdnk/.local/lib/python3.10/site-packages (from ipykernel>=5.2.0->napari-console>=0.0.6->napari) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/longdnk/.local/lib/python3.10/site-packages (from ipykernel>=5.2.0->napari-console>=0.0.6->napari) (8.6.0)
# Requirement already satisfied: comm>=0.1.1 in /home/longdnk/.local/lib/python3.10/site-packages (from ipykernel>=5.2.0->napari-console>=0.0.6->napari) (0.2.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/longdnk/.local/lib/python3.10/site-packages (from ipykernel>=5.2.0->napari-console>=0.0.6->napari) (5.6.0)
# Requirement already satisfied: traitlets>=5.4.0 in /home/longdnk/.local/lib/python3.10/site-packages (from ipykernel>=5.2.0->napari-console>=0.0.6->napari) (5.14.0)
# Requirement already satisfied: nest-asyncio in /home/longdnk/.local/lib/python3.10/site-packages (from ipykernel>=5.2.0->napari-console>=0.0.6->napari) (1.5.8)
# Requirement already satisfied: pyzmq>=24 in /home/longdnk/.local/lib/python3.10/site-packages (from ipykernel>=5.2.0->napari-console>=0.0.6->napari) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in /home/longdnk/.local/lib/python3.10/site-packages (from ipykernel>=5.2.0->napari-console>=0.0.6->napari) (6.4)
# Requirement already satisfied: stack-data in /home/longdnk/.local/lib/python3.10/site-packages (from IPython>=7.7.0->napari-console>=0.0.6->napari) (0.6.3)
# Requirement already satisfied: jedi>=0.16 in /home/longdnk/.local/lib/python3.10/site-packages (from IPython>=7.7.0->napari-console>=0.0.6->napari) (0.19.1)
# Requirement already satisfied: decorator in /home/longdnk/.local/lib/python3.10/site-packages (from IPython>=7.7.0->napari-console>=0.0.6->napari) (5.1.1)
# Requirement already satisfied: pexpect>4.3 in /home/longdnk/.local/lib/python3.10/site-packages (from IPython>=7.7.0->napari-console>=0.0.6->napari) (4.9.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/longdnk/.local/lib/python3.10/site-packages (from IPython>=7.7.0->napari-console>=0.0.6->napari) (3.0.43)
# Requirement already satisfied: exceptiongroup in /home/longdnk/.local/lib/python3.10/site-packages (from IPython>=7.7.0->napari-console>=0.0.6->napari) (1.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/longdnk/.local/lib/python3.10/site-packages (from Jinja2>=2.10->numpydoc>=0.9.2->napari) (2.1.3)
# Requirement already satisfied: locket in /home/longdnk/.local/lib/python3.10/site-packages (from partd>=1.2.0->dask[array]!=2.28.0,>=2.15.0->napari) (1.0.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/longdnk/.local/lib/python3.10/site-packages (from pooch>=1.6.0->scikit-image[data]>=0.19.1->napari) (4.1.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->napari) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.5.0->sphinx<5,>=4.3.0->napari) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests>=2.5.0->sphinx<5,>=4.3.0->napari) (1.26.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/longdnk/.local/lib/python3.10/site-packages (from requests>=2.5.0->sphinx<5,>=4.3.0->napari) (3.3.2)
# Requirement already satisfied: pyconify>=0.1.4 in /home/longdnk/.local/lib/python3.10/site-packages (from superqt>=0.4.1->napari) (0.1.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/longdnk/.local/lib/python3.10/site-packages (from rich->npe2>=0.5.2->napari) (3.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/longdnk/.local/lib/python3.10/site-packages (from jedi>=0.16->IPython>=7.7.0->napari-console>=0.0.6->napari) (0.8.3)
# Requirement already satisfied: mdurl~=0.1 in /home/longdnk/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->npe2>=0.5.2->napari) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/longdnk/.local/lib/python3.10/site-packages (from pexpect>4.3->IPython>=7.7.0->napari-console>=0.0.6->napari) (0.7.0)
# Requirement already satisfied: wcwidth in /home/longdnk/.local/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython>=7.7.0->napari-console>=0.0.6->napari) (0.2.12)
# Requirement already satisfied: asttokens>=2.1.0 in /home/longdnk/.local/lib/python3.10/site-packages (from stack-data->IPython>=7.7.0->napari-console>=0.0.6->napari) (2.4.1)
# Requirement already satisfied: executing>=1.2.0 in /home/longdnk/.local/lib/python3.10/site-packages (from stack-data->IPython>=7.7.0->napari-console>=0.0.6->napari) (2.0.1)
# Requirement already satisfied: pure-eval in /home/longdnk/.local/lib/python3.10/site-packages (from stack-data->IPython>=7.7.0->napari-console>=0.0.6->napari) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip uninstall PyQt5 -y
# Out:
# Found existing installation: PyQt5 5.15.10
# Uninstalling PyQt5-5.15.10:
#   Successfully uninstalled PyQt5-5.15.10
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install PyQt5
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting PyQt5
#   Using cached PyQt5-5.15.10-cp37-abi3-manylinux_2_17_x86_64.whl (8.2 MB)
# Requirement already satisfied: PyQt5-sip<13,>=12.13 in /home/longdnk/.local/lib/python3.10/site-packages (from PyQt5) (12.13.0)
# Requirement already satisfied: PyQt5-Qt5>=5.15.2 in /home/longdnk/.local/lib/python3.10/site-packages (from PyQt5) (5.15.2)
# Installing collected packages: PyQt5
#   WARNING: The scripts pylupdate5, pyrcc5 and pyuic5 are installed in '/home/longdnk/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed PyQt5-5.15.10
# Note: you may need to restart the kernel to use updated packages.

# %%
import napari
from napari.utils import nbscreenshot

# %%
viewer = napari.Viewer()

# %%
nbscreenshot(viewer)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/napari/window.py:14
#      13 try:
# ---> 14     from napari._qt import Window
#      16 except ImportError as e:
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/__init__.py:52
#      49     warn(message=warn_message, stacklevel=1)
# ---> 52 from napari._qt.qt_event_loop import get_app, gui_qt, quit_app, run
#      53 from napari._qt.qt_main_window import Window
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/qt_event_loop.py:15
#      14 from napari import Viewer, __version__
# ---> 15 from napari._qt.dialogs.qt_notification import NapariQtNotification
#      16 from napari._qt.qt_event_filters import QtToolTipEventFilter
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/dialogs/qt_notification.py:29
#      28 from napari._qt.code_syntax_highlight import Pylighter
# ---> 29 from napari._qt.qt_resources import QColoredSVGIcon
#      30 from napari.settings import get_settings
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/qt_resources/__init__.py:4
#       2 from typing import List, Optional
# ----> 4 from napari._qt.qt_resources._svg import QColoredSVGIcon
#       5 from napari.settings import get_settings
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/qt_resources/_svg.py:8
#       7 from qtpy.QtGui import QIcon, QIconEngine, QImage, QPainter, QPixmap
# ----> 8 from qtpy.QtSvg import QSvgRenderer
#      11 class QColoredSVGIcon(QIcon):
#
# File ~/.local/lib/python3.10/site-packages/qtpy/QtSvg.py:13
#      12 if PYQT5:
# ---> 13     from PyQt5.QtSvg import *
#      14 elif PYQT6:
#
# ModuleNotFoundError: No module named 'PyQt5.QtSvg'
#
# The above exception was the direct cause of the following exception:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/IPython/core/formatters.py:344, in BaseFormatter.__call__(self, obj)
#     342     method = get_real_method(obj, self.print_method)
#     343     if method is not None:
# --> 344         return method()
#     345     return None
#     346 else:
#
# File ~/.local/lib/python3.10/site-packages/napari/utils/notebook_display.py:125, in NotebookScreenshot._repr_html_(self)
#     124 def _repr_html_(self):
# --> 125     png = self._repr_png_()
#     126     url = 'data:image/png;base64,' + base64.b64encode(png).decode('utf-8')
#     127     _alt = html.escape(self.alt_text) if self.alt_text is not None else ''
#
# File ~/.local/lib/python3.10/site-packages/napari/utils/notebook_display.py:115, in NotebookScreenshot._repr_png_(self)
#     112 from napari._qt.qt_event_loop import get_app
#     114 get_app().processEvents()
# --> 115 self.image = self.viewer.screenshot(
#     116     canvas_only=self.canvas_only, flash=False
#     117 )
#     118 with BytesIO() as file_obj:
#     119     imsave(file_obj, self.image, format='png')
#
# File ~/.local/lib/python3.10/site-packages/napari/viewer.py:129, in Viewer.screenshot(self, path, size, scale, canvas_only, flash)
#      93 def screenshot(
#      94     self,
#      95     path=None,
#    (...)
#     100     flash: bool = True,
#     101 ):
#     102     """Take currently displayed screen and convert to an image array.
#     103
#     104     Parameters
#    (...)
#     127         upper-left corner of the rendered region.
#     128     """
# --> 129     return self.window.screenshot(
#     130         path=path,
#     131         size=size,
#     132         scale=scale,
#     133         flash=flash,
#     134         canvas_only=canvas_only,
#     135     )
#
# File ~/.local/lib/python3.10/site-packages/napari/window.py:27, in Window.__getattr__(self, name)
#      26 def __getattr__(self, name):
# ---> 27     raise type(err)(
#      28         trans._(
#      29             "An error occured when importing Qt dependencies.  Cannot show napari window.  See cause above",
#      30         )
#      31     ) from err
#
# ModuleNotFoundError: An error occured when importing Qt dependencies.  Cannot show napari window.  See cause above
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/napari/window.py:14
#      13 try:
# ---> 14     from napari._qt import Window
#      16 except ImportError as e:
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/__init__.py:52
#      49     warn(message=warn_message, stacklevel=1)
# ---> 52 from napari._qt.qt_event_loop import get_app, gui_qt, quit_app, run
#      53 from napari._qt.qt_main_window import Window
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/qt_event_loop.py:15
#      14 from napari import Viewer, __version__
# ---> 15 from napari._qt.dialogs.qt_notification import NapariQtNotification
#      16 from napari._qt.qt_event_filters import QtToolTipEventFilter
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/dialogs/qt_notification.py:29
#      28 from napari._qt.code_syntax_highlight import Pylighter
# ---> 29 from napari._qt.qt_resources import QColoredSVGIcon
#      30 from napari.settings import get_settings
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/qt_resources/__init__.py:4
#       2 from typing import List, Optional
# ----> 4 from napari._qt.qt_resources._svg import QColoredSVGIcon
#       5 from napari.settings import get_settings
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/qt_resources/_svg.py:8
#       7 from qtpy.QtGui import QIcon, QIconEngine, QImage, QPainter, QPixmap
# ----> 8 from qtpy.QtSvg import QSvgRenderer
#      11 class QColoredSVGIcon(QIcon):
#
# File ~/.local/lib/python3.10/site-packages/qtpy/QtSvg.py:13
#      12 if PYQT5:
# ---> 13     from PyQt5.QtSvg import *
#      14 elif PYQT6:
#
# ModuleNotFoundError: No module named 'PyQt5.QtSvg'
#
# The above exception was the direct cause of the following exception:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/IPython/core/formatters.py:344, in BaseFormatter.__call__(self, obj)
#     342     method = get_real_method(obj, self.print_method)
#     343     if method is not None:
# --> 344         return method()
#     345     return None
#     346 else:
#
# File ~/.local/lib/python3.10/site-packages/napari/utils/notebook_display.py:115, in NotebookScreenshot._repr_png_(self)
#     112 from napari._qt.qt_event_loop import get_app
#     114 get_app().processEvents()
# --> 115 self.image = self.viewer.screenshot(
#     116     canvas_only=self.canvas_only, flash=False
#     117 )
#     118 with BytesIO() as file_obj:
#     119     imsave(file_obj, self.image, format='png')
#
# File ~/.local/lib/python3.10/site-packages/napari/viewer.py:129, in Viewer.screenshot(self, path, size, scale, canvas_only, flash)
#      93 def screenshot(
#      94     self,
#      95     path=None,
#    (...)
#     100     flash: bool = True,
#     101 ):
#     102     """Take currently displayed screen and convert to an image array.
#     103
#     104     Parameters
#    (...)
#     127         upper-left corner of the rendered region.
#     128     """
# --> 129     return self.window.screenshot(
#     130         path=path,
#     131         size=size,
#     132         scale=scale,
#     133         flash=flash,
#     134         canvas_only=canvas_only,
#     135     )
#
# File ~/.local/lib/python3.10/site-packages/napari/window.py:27, in Window.__getattr__(self, name)
#      26 def __getattr__(self, name):
# ---> 27     raise type(err)(
#      28         trans._(
#      29             "An error occured when importing Qt dependencies.  Cannot show napari window.  See cause above",
#      30         )
#      31     ) from err
#
# ModuleNotFoundError: An error occured when importing Qt dependencies.  Cannot show napari window.  See cause above

# %%
viewer.add_image(image[:, :, 0], colormap='red', name='cytoplasm')
viewer.add_image(image[:, :, 1], colormap='green', name='signal')
viewer.add_image(image[:, :, 2], colormap='blue', name='nuclei');

# %%
viewer.add_labels(masks);

# %%
viewer.add_labels(masks);

# %%
nbscreenshot(viewer)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/napari/window.py:14
#      13 try:
# ---> 14     from napari._qt import Window
#      16 except ImportError as e:
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/__init__.py:52
#      49     warn(message=warn_message, stacklevel=1)
# ---> 52 from napari._qt.qt_event_loop import get_app, gui_qt, quit_app, run
#      53 from napari._qt.qt_main_window import Window
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/qt_event_loop.py:15
#      14 from napari import Viewer, __version__
# ---> 15 from napari._qt.dialogs.qt_notification import NapariQtNotification
#      16 from napari._qt.qt_event_filters import QtToolTipEventFilter
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/dialogs/qt_notification.py:29
#      28 from napari._qt.code_syntax_highlight import Pylighter
# ---> 29 from napari._qt.qt_resources import QColoredSVGIcon
#      30 from napari.settings import get_settings
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/qt_resources/__init__.py:4
#       2 from typing import List, Optional
# ----> 4 from napari._qt.qt_resources._svg import QColoredSVGIcon
#       5 from napari.settings import get_settings
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/qt_resources/_svg.py:8
#       7 from qtpy.QtGui import QIcon, QIconEngine, QImage, QPainter, QPixmap
# ----> 8 from qtpy.QtSvg import QSvgRenderer
#      11 class QColoredSVGIcon(QIcon):
#
# File ~/.local/lib/python3.10/site-packages/qtpy/QtSvg.py:13
#      12 if PYQT5:
# ---> 13     from PyQt5.QtSvg import *
#      14 elif PYQT6:
#
# ModuleNotFoundError: No module named 'PyQt5.QtSvg'
#
# The above exception was the direct cause of the following exception:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/IPython/core/formatters.py:344, in BaseFormatter.__call__(self, obj)
#     342     method = get_real_method(obj, self.print_method)
#     343     if method is not None:
# --> 344         return method()
#     345     return None
#     346 else:
#
# File ~/.local/lib/python3.10/site-packages/napari/utils/notebook_display.py:125, in NotebookScreenshot._repr_html_(self)
#     124 def _repr_html_(self):
# --> 125     png = self._repr_png_()
#     126     url = 'data:image/png;base64,' + base64.b64encode(png).decode('utf-8')
#     127     _alt = html.escape(self.alt_text) if self.alt_text is not None else ''
#
# File ~/.local/lib/python3.10/site-packages/napari/utils/notebook_display.py:115, in NotebookScreenshot._repr_png_(self)
#     112 from napari._qt.qt_event_loop import get_app
#     114 get_app().processEvents()
# --> 115 self.image = self.viewer.screenshot(
#     116     canvas_only=self.canvas_only, flash=False
#     117 )
#     118 with BytesIO() as file_obj:
#     119     imsave(file_obj, self.image, format='png')
#
# File ~/.local/lib/python3.10/site-packages/napari/viewer.py:129, in Viewer.screenshot(self, path, size, scale, canvas_only, flash)
#      93 def screenshot(
#      94     self,
#      95     path=None,
#    (...)
#     100     flash: bool = True,
#     101 ):
#     102     """Take currently displayed screen and convert to an image array.
#     103
#     104     Parameters
#    (...)
#     127         upper-left corner of the rendered region.
#     128     """
# --> 129     return self.window.screenshot(
#     130         path=path,
#     131         size=size,
#     132         scale=scale,
#     133         flash=flash,
#     134         canvas_only=canvas_only,
#     135     )
#
# File ~/.local/lib/python3.10/site-packages/napari/window.py:27, in Window.__getattr__(self, name)
#      26 def __getattr__(self, name):
# ---> 27     raise type(err)(
#      28         trans._(
#      29             "An error occured when importing Qt dependencies.  Cannot show napari window.  See cause above",
#      30         )
#      31     ) from err
#
# ModuleNotFoundError: An error occured when importing Qt dependencies.  Cannot show napari window.  See cause above
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/napari/window.py:14
#      13 try:
# ---> 14     from napari._qt import Window
#      16 except ImportError as e:
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/__init__.py:52
#      49     warn(message=warn_message, stacklevel=1)
# ---> 52 from napari._qt.qt_event_loop import get_app, gui_qt, quit_app, run
#      53 from napari._qt.qt_main_window import Window
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/qt_event_loop.py:15
#      14 from napari import Viewer, __version__
# ---> 15 from napari._qt.dialogs.qt_notification import NapariQtNotification
#      16 from napari._qt.qt_event_filters import QtToolTipEventFilter
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/dialogs/qt_notification.py:29
#      28 from napari._qt.code_syntax_highlight import Pylighter
# ---> 29 from napari._qt.qt_resources import QColoredSVGIcon
#      30 from napari.settings import get_settings
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/qt_resources/__init__.py:4
#       2 from typing import List, Optional
# ----> 4 from napari._qt.qt_resources._svg import QColoredSVGIcon
#       5 from napari.settings import get_settings
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/qt_resources/_svg.py:8
#       7 from qtpy.QtGui import QIcon, QIconEngine, QImage, QPainter, QPixmap
# ----> 8 from qtpy.QtSvg import QSvgRenderer
#      11 class QColoredSVGIcon(QIcon):
#
# File ~/.local/lib/python3.10/site-packages/qtpy/QtSvg.py:13
#      12 if PYQT5:
# ---> 13     from PyQt5.QtSvg import *
#      14 elif PYQT6:
#
# ModuleNotFoundError: No module named 'PyQt5.QtSvg'
#
# The above exception was the direct cause of the following exception:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/IPython/core/formatters.py:344, in BaseFormatter.__call__(self, obj)
#     342     method = get_real_method(obj, self.print_method)
#     343     if method is not None:
# --> 344         return method()
#     345     return None
#     346 else:
#
# File ~/.local/lib/python3.10/site-packages/napari/utils/notebook_display.py:115, in NotebookScreenshot._repr_png_(self)
#     112 from napari._qt.qt_event_loop import get_app
#     114 get_app().processEvents()
# --> 115 self.image = self.viewer.screenshot(
#     116     canvas_only=self.canvas_only, flash=False
#     117 )
#     118 with BytesIO() as file_obj:
#     119     imsave(file_obj, self.image, format='png')
#
# File ~/.local/lib/python3.10/site-packages/napari/viewer.py:129, in Viewer.screenshot(self, path, size, scale, canvas_only, flash)
#      93 def screenshot(
#      94     self,
#      95     path=None,
#    (...)
#     100     flash: bool = True,
#     101 ):
#     102     """Take currently displayed screen and convert to an image array.
#     103
#     104     Parameters
#    (...)
#     127         upper-left corner of the rendered region.
#     128     """
# --> 129     return self.window.screenshot(
#     130         path=path,
#     131         size=size,
#     132         scale=scale,
#     133         flash=flash,
#     134         canvas_only=canvas_only,
#     135     )
#
# File ~/.local/lib/python3.10/site-packages/napari/window.py:27, in Window.__getattr__(self, name)
#      26 def __getattr__(self, name):
# ---> 27     raise type(err)(
#      28         trans._(
#      29             "An error occured when importing Qt dependencies.  Cannot show napari window.  See cause above",
#      30         )
#      31     ) from err
#
# ModuleNotFoundError: An error occured when importing Qt dependencies.  Cannot show napari window.  See cause above

# %%
nbscreenshot(viewer)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/napari/window.py:14
#      13 try:
# ---> 14     from napari._qt import Window
#      16 except ImportError as e:
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/__init__.py:52
#      49     warn(message=warn_message, stacklevel=1)
# ---> 52 from napari._qt.qt_event_loop import get_app, gui_qt, quit_app, run
#      53 from napari._qt.qt_main_window import Window
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/qt_event_loop.py:15
#      14 from napari import Viewer, __version__
# ---> 15 from napari._qt.dialogs.qt_notification import NapariQtNotification
#      16 from napari._qt.qt_event_filters import QtToolTipEventFilter
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/dialogs/qt_notification.py:29
#      28 from napari._qt.code_syntax_highlight import Pylighter
# ---> 29 from napari._qt.qt_resources import QColoredSVGIcon
#      30 from napari.settings import get_settings
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/qt_resources/__init__.py:4
#       2 from typing import List, Optional
# ----> 4 from napari._qt.qt_resources._svg import QColoredSVGIcon
#       5 from napari.settings import get_settings
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/qt_resources/_svg.py:8
#       7 from qtpy.QtGui import QIcon, QIconEngine, QImage, QPainter, QPixmap
# ----> 8 from qtpy.QtSvg import QSvgRenderer
#      11 class QColoredSVGIcon(QIcon):
#
# File ~/.local/lib/python3.10/site-packages/qtpy/QtSvg.py:13
#      12 if PYQT5:
# ---> 13     from PyQt5.QtSvg import *
#      14 elif PYQT6:
#
# ModuleNotFoundError: No module named 'PyQt5.QtSvg'
#
# The above exception was the direct cause of the following exception:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/IPython/core/formatters.py:344, in BaseFormatter.__call__(self, obj)
#     342     method = get_real_method(obj, self.print_method)
#     343     if method is not None:
# --> 344         return method()
#     345     return None
#     346 else:
#
# File ~/.local/lib/python3.10/site-packages/napari/utils/notebook_display.py:125, in NotebookScreenshot._repr_html_(self)
#     124 def _repr_html_(self):
# --> 125     png = self._repr_png_()
#     126     url = 'data:image/png;base64,' + base64.b64encode(png).decode('utf-8')
#     127     _alt = html.escape(self.alt_text) if self.alt_text is not None else ''
#
# File ~/.local/lib/python3.10/site-packages/napari/utils/notebook_display.py:115, in NotebookScreenshot._repr_png_(self)
#     112 from napari._qt.qt_event_loop import get_app
#     114 get_app().processEvents()
# --> 115 self.image = self.viewer.screenshot(
#     116     canvas_only=self.canvas_only, flash=False
#     117 )
#     118 with BytesIO() as file_obj:
#     119     imsave(file_obj, self.image, format='png')
#
# File ~/.local/lib/python3.10/site-packages/napari/viewer.py:129, in Viewer.screenshot(self, path, size, scale, canvas_only, flash)
#      93 def screenshot(
#      94     self,
#      95     path=None,
#    (...)
#     100     flash: bool = True,
#     101 ):
#     102     """Take currently displayed screen and convert to an image array.
#     103
#     104     Parameters
#    (...)
#     127         upper-left corner of the rendered region.
#     128     """
# --> 129     return self.window.screenshot(
#     130         path=path,
#     131         size=size,
#     132         scale=scale,
#     133         flash=flash,
#     134         canvas_only=canvas_only,
#     135     )
#
# File ~/.local/lib/python3.10/site-packages/napari/window.py:27, in Window.__getattr__(self, name)
#      26 def __getattr__(self, name):
# ---> 27     raise type(err)(
#      28         trans._(
#      29             "An error occured when importing Qt dependencies.  Cannot show napari window.  See cause above",
#      30         )
#      31     ) from err
#
# ModuleNotFoundError: An error occured when importing Qt dependencies.  Cannot show napari window.  See cause above
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/napari/window.py:14
#      13 try:
# ---> 14     from napari._qt import Window
#      16 except ImportError as e:
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/__init__.py:52
#      49     warn(message=warn_message, stacklevel=1)
# ---> 52 from napari._qt.qt_event_loop import get_app, gui_qt, quit_app, run
#      53 from napari._qt.qt_main_window import Window
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/qt_event_loop.py:15
#      14 from napari import Viewer, __version__
# ---> 15 from napari._qt.dialogs.qt_notification import NapariQtNotification
#      16 from napari._qt.qt_event_filters import QtToolTipEventFilter
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/dialogs/qt_notification.py:29
#      28 from napari._qt.code_syntax_highlight import Pylighter
# ---> 29 from napari._qt.qt_resources import QColoredSVGIcon
#      30 from napari.settings import get_settings
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/qt_resources/__init__.py:4
#       2 from typing import List, Optional
# ----> 4 from napari._qt.qt_resources._svg import QColoredSVGIcon
#       5 from napari.settings import get_settings
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/qt_resources/_svg.py:8
#       7 from qtpy.QtGui import QIcon, QIconEngine, QImage, QPainter, QPixmap
# ----> 8 from qtpy.QtSvg import QSvgRenderer
#      11 class QColoredSVGIcon(QIcon):
#
# File ~/.local/lib/python3.10/site-packages/qtpy/QtSvg.py:13
#      12 if PYQT5:
# ---> 13     from PyQt5.QtSvg import *
#      14 elif PYQT6:
#
# ModuleNotFoundError: No module named 'PyQt5.QtSvg'
#
# The above exception was the direct cause of the following exception:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/IPython/core/formatters.py:344, in BaseFormatter.__call__(self, obj)
#     342     method = get_real_method(obj, self.print_method)
#     343     if method is not None:
# --> 344         return method()
#     345     return None
#     346 else:
#
# File ~/.local/lib/python3.10/site-packages/napari/utils/notebook_display.py:115, in NotebookScreenshot._repr_png_(self)
#     112 from napari._qt.qt_event_loop import get_app
#     114 get_app().processEvents()
# --> 115 self.image = self.viewer.screenshot(
#     116     canvas_only=self.canvas_only, flash=False
#     117 )
#     118 with BytesIO() as file_obj:
#     119     imsave(file_obj, self.image, format='png')
#
# File ~/.local/lib/python3.10/site-packages/napari/viewer.py:129, in Viewer.screenshot(self, path, size, scale, canvas_only, flash)
#      93 def screenshot(
#      94     self,
#      95     path=None,
#    (...)
#     100     flash: bool = True,
#     101 ):
#     102     """Take currently displayed screen and convert to an image array.
#     103
#     104     Parameters
#    (...)
#     127         upper-left corner of the rendered region.
#     128     """
# --> 129     return self.window.screenshot(
#     130         path=path,
#     131         size=size,
#     132         scale=scale,
#     133         flash=flash,
#     134         canvas_only=canvas_only,
#     135     )
#
# File ~/.local/lib/python3.10/site-packages/napari/window.py:27, in Window.__getattr__(self, name)
#      26 def __getattr__(self, name):
# ---> 27     raise type(err)(
#      28         trans._(
#      29             "An error occured when importing Qt dependencies.  Cannot show napari window.  See cause above",
#      30         )
#      31     ) from err
#
# ModuleNotFoundError: An error occured when importing Qt dependencies.  Cannot show napari window.  See cause above

# %%
import skimage
from magicgui import magicgui
from napari.types import ImageData, LabelsData

# %%
def my_thresholder(image: ImageData, th_level: int = 0) -> LabelsData:
    label_image = image > th_level
    label_image = skimage.morphology.label(label_image)

    return (label_image)


thresholding_widget = magicgui(my_thresholder)

# %%
viewer.window.add_dock_widget(thresholding_widget, area='right')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/napari/window.py:14
#      13 try:
# ---> 14     from napari._qt import Window
#      16 except ImportError as e:
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/__init__.py:52
#      49     warn(message=warn_message, stacklevel=1)
# ---> 52 from napari._qt.qt_event_loop import get_app, gui_qt, quit_app, run
#      53 from napari._qt.qt_main_window import Window
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/qt_event_loop.py:15
#      14 from napari import Viewer, __version__
# ---> 15 from napari._qt.dialogs.qt_notification import NapariQtNotification
#      16 from napari._qt.qt_event_filters import QtToolTipEventFilter
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/dialogs/qt_notification.py:29
#      28 from napari._qt.code_syntax_highlight import Pylighter
# ---> 29 from napari._qt.qt_resources import QColoredSVGIcon
#      30 from napari.settings import get_settings
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/qt_resources/__init__.py:4
#       2 from typing import List, Optional
# ----> 4 from napari._qt.qt_resources._svg import QColoredSVGIcon
#       5 from napari.settings import get_settings
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/qt_resources/_svg.py:8
#       7 from qtpy.QtGui import QIcon, QIconEngine, QImage, QPainter, QPixmap
# ----> 8 from qtpy.QtSvg import QSvgRenderer
#      11 class QColoredSVGIcon(QIcon):
#
# File ~/.local/lib/python3.10/site-packages/qtpy/QtSvg.py:13
#      12 if PYQT5:
# ---> 13     from PyQt5.QtSvg import *
#      14 elif PYQT6:
#
# ModuleNotFoundError: No module named 'PyQt5.QtSvg'
#
# The above exception was the direct cause of the following exception:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 viewer.window.add_dock_widget(thresholding_widget, area='right')
#
# File ~/.local/lib/python3.10/site-packages/napari/window.py:27, in Window.__getattr__(self, name)
#      26 def __getattr__(self, name):
# ---> 27     raise type(err)(
#      28         trans._(
#      29             "An error occured when importing Qt dependencies.  Cannot show napari window.  See cause above",
#      30         )
#      31     ) from err
#
# ModuleNotFoundError: An error occured when importing Qt dependencies.  Cannot show napari window.  See cause above

# %%
nbscreenshot(viewer)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/napari/window.py:14
#      13 try:
# ---> 14     from napari._qt import Window
#      16 except ImportError as e:
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/__init__.py:52
#      49     warn(message=warn_message, stacklevel=1)
# ---> 52 from napari._qt.qt_event_loop import get_app, gui_qt, quit_app, run
#      53 from napari._qt.qt_main_window import Window
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/qt_event_loop.py:15
#      14 from napari import Viewer, __version__
# ---> 15 from napari._qt.dialogs.qt_notification import NapariQtNotification
#      16 from napari._qt.qt_event_filters import QtToolTipEventFilter
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/dialogs/qt_notification.py:29
#      28 from napari._qt.code_syntax_highlight import Pylighter
# ---> 29 from napari._qt.qt_resources import QColoredSVGIcon
#      30 from napari.settings import get_settings
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/qt_resources/__init__.py:4
#       2 from typing import List, Optional
# ----> 4 from napari._qt.qt_resources._svg import QColoredSVGIcon
#       5 from napari.settings import get_settings
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/qt_resources/_svg.py:8
#       7 from qtpy.QtGui import QIcon, QIconEngine, QImage, QPainter, QPixmap
# ----> 8 from qtpy.QtSvg import QSvgRenderer
#      11 class QColoredSVGIcon(QIcon):
#
# File ~/.local/lib/python3.10/site-packages/qtpy/QtSvg.py:13
#      12 if PYQT5:
# ---> 13     from PyQt5.QtSvg import *
#      14 elif PYQT6:
#
# ModuleNotFoundError: No module named 'PyQt5.QtSvg'
#
# The above exception was the direct cause of the following exception:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/IPython/core/formatters.py:344, in BaseFormatter.__call__(self, obj)
#     342     method = get_real_method(obj, self.print_method)
#     343     if method is not None:
# --> 344         return method()
#     345     return None
#     346 else:
#
# File ~/.local/lib/python3.10/site-packages/napari/utils/notebook_display.py:125, in NotebookScreenshot._repr_html_(self)
#     124 def _repr_html_(self):
# --> 125     png = self._repr_png_()
#     126     url = 'data:image/png;base64,' + base64.b64encode(png).decode('utf-8')
#     127     _alt = html.escape(self.alt_text) if self.alt_text is not None else ''
#
# File ~/.local/lib/python3.10/site-packages/napari/utils/notebook_display.py:115, in NotebookScreenshot._repr_png_(self)
#     112 from napari._qt.qt_event_loop import get_app
#     114 get_app().processEvents()
# --> 115 self.image = self.viewer.screenshot(
#     116     canvas_only=self.canvas_only, flash=False
#     117 )
#     118 with BytesIO() as file_obj:
#     119     imsave(file_obj, self.image, format='png')
#
# File ~/.local/lib/python3.10/site-packages/napari/viewer.py:129, in Viewer.screenshot(self, path, size, scale, canvas_only, flash)
#      93 def screenshot(
#      94     self,
#      95     path=None,
#    (...)
#     100     flash: bool = True,
#     101 ):
#     102     """Take currently displayed screen and convert to an image array.
#     103
#     104     Parameters
#    (...)
#     127         upper-left corner of the rendered region.
#     128     """
# --> 129     return self.window.screenshot(
#     130         path=path,
#     131         size=size,
#     132         scale=scale,
#     133         flash=flash,
#     134         canvas_only=canvas_only,
#     135     )
#
# File ~/.local/lib/python3.10/site-packages/napari/window.py:27, in Window.__getattr__(self, name)
#      26 def __getattr__(self, name):
# ---> 27     raise type(err)(
#      28         trans._(
#      29             "An error occured when importing Qt dependencies.  Cannot show napari window.  See cause above",
#      30         )
#      31     ) from err
#
# ModuleNotFoundError: An error occured when importing Qt dependencies.  Cannot show napari window.  See cause above
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/napari/window.py:14
#      13 try:
# ---> 14     from napari._qt import Window
#      16 except ImportError as e:
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/__init__.py:52
#      49     warn(message=warn_message, stacklevel=1)
# ---> 52 from napari._qt.qt_event_loop import get_app, gui_qt, quit_app, run
#      53 from napari._qt.qt_main_window import Window
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/qt_event_loop.py:15
#      14 from napari import Viewer, __version__
# ---> 15 from napari._qt.dialogs.qt_notification import NapariQtNotification
#      16 from napari._qt.qt_event_filters import QtToolTipEventFilter
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/dialogs/qt_notification.py:29
#      28 from napari._qt.code_syntax_highlight import Pylighter
# ---> 29 from napari._qt.qt_resources import QColoredSVGIcon
#      30 from napari.settings import get_settings
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/qt_resources/__init__.py:4
#       2 from typing import List, Optional
# ----> 4 from napari._qt.qt_resources._svg import QColoredSVGIcon
#       5 from napari.settings import get_settings
#
# File ~/.local/lib/python3.10/site-packages/napari/_qt/qt_resources/_svg.py:8
#       7 from qtpy.QtGui import QIcon, QIconEngine, QImage, QPainter, QPixmap
# ----> 8 from qtpy.QtSvg import QSvgRenderer
#      11 class QColoredSVGIcon(QIcon):
#
# File ~/.local/lib/python3.10/site-packages/qtpy/QtSvg.py:13
#      12 if PYQT5:
# ---> 13     from PyQt5.QtSvg import *
#      14 elif PYQT6:
#
# ModuleNotFoundError: No module named 'PyQt5.QtSvg'
#
# The above exception was the direct cause of the following exception:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/IPython/core/formatters.py:344, in BaseFormatter.__call__(self, obj)
#     342     method = get_real_method(obj, self.print_method)
#     343     if method is not None:
# --> 344         return method()
#     345     return None
#     346 else:
#
# File ~/.local/lib/python3.10/site-packages/napari/utils/notebook_display.py:115, in NotebookScreenshot._repr_png_(self)
#     112 from napari._qt.qt_event_loop import get_app
#     114 get_app().processEvents()
# --> 115 self.image = self.viewer.screenshot(
#     116     canvas_only=self.canvas_only, flash=False
#     117 )
#     118 with BytesIO() as file_obj:
#     119     imsave(file_obj, self.image, format='png')
#
# File ~/.local/lib/python3.10/site-packages/napari/viewer.py:129, in Viewer.screenshot(self, path, size, scale, canvas_only, flash)
#      93 def screenshot(
#      94     self,
#      95     path=None,
#    (...)
#     100     flash: bool = True,
#     101 ):
#     102     """Take currently displayed screen and convert to an image array.
#     103
#     104     Parameters
#    (...)
#     127         upper-left corner of the rendered region.
#     128     """
# --> 129     return self.window.screenshot(
#     130         path=path,
#     131         size=size,
#     132         scale=scale,
#     133         flash=flash,
#     134         canvas_only=canvas_only,
#     135     )
#
# File ~/.local/lib/python3.10/site-packages/napari/window.py:27, in Window.__getattr__(self, name)
#      26 def __getattr__(self, name):
# ---> 27     raise type(err)(
#      28         trans._(
#      29             "An error occured when importing Qt dependencies.  Cannot show napari window.  See cause above",
#      30         )
#      31     ) from err
#
# ModuleNotFoundError: An error occured when importing Qt dependencies.  Cannot show napari window.  See cause above
